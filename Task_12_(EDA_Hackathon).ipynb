# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data sets/data (2).csv')

# %%
data.head()
# Out:
#    Unnamed: 0              Id  ... winPoints winPlacePerc
# 0     2093518  a3e3cea9f2e314  ...      1525       0.0667
# 1     3701672  43e4be7ad72cc7  ...      1516       0.5862
# 2     2059784  9a68690e31fdff  ...         0       0.8105
# 3     1302036  b147e1bd448fc4  ...      1515       0.5556
# 4      297180  d818b4edd59612  ...         0       0.6429
#
# [5 rows x 30 columns]

# %%
data.tail()
# Out:
#          Unnamed: 0              Id  ... winPoints winPlacePerc
# 1111737     4209703  43739241d6a8e8  ...         0       0.3929
# 1111738     4311549  d57c8a22a9e38b  ...         0       0.8542
# 1111739     3521011  c7ad131758ba55  ...         0       0.7174
# 1111740     2138826  8237d06ea2c508  ...         0       0.9000
# 1111741      609836  9beb0064c56445  ...      1611       1.0000
#
# [5 rows x 30 columns]

# %%
data.info()# to see what data type we have for the columns in the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111742 entries, 0 to 1111741
# Data columns (total 30 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Unnamed: 0       1111742 non-null  int64
#  1   Id               1111742 non-null  object
#  2   groupId          1111742 non-null  object
#  3   matchId          1111742 non-null  object
#  4   assists          1111742 non-null  int64
#  5   boosts           1111742 non-null  int64
#  6   damageDealt      1111742 non-null  float64
#  7   DBNOs            1111742 non-null  int64
#  8   headshotKills    1111742 non-null  int64
#  9   heals            1111742 non-null  int64
#  10  killPlace        1111742 non-null  int64
#  11  killPoints       1111742 non-null  int64
#  12  kills            1111742 non-null  int64
#  13  killStreaks      1111742 non-null  int64
#  14  longestKill      1111742 non-null  float64
#  15  matchDuration    1111742 non-null  int64
# ...

# %%
data.describe(include="all")
# Out:
#           Unnamed: 0              Id  ...     winPoints  winPlacePerc
# count   1.111742e+06         1111742  ...  1.111742e+06  1.111741e+06
# unique           NaN         1111742  ...           NaN           NaN
# top              NaN  a953e1144a9f50  ...           NaN           NaN
# freq             NaN               1  ...           NaN           NaN
# mean    2.224362e+06             NaN  ...  6.057065e+02  4.727868e-01
# std     1.283879e+06             NaN  ...  7.395140e+02  3.073771e-01
# min     6.000000e+00             NaN  ...  0.000000e+00  0.000000e+00
# 25%     1.112440e+06             NaN  ...  0.000000e+00  2.000000e-01
# 50%     2.223772e+06             NaN  ...  0.000000e+00  4.583000e-01
# 75%     3.337954e+06             NaN  ...  1.495000e+03  7.407000e-01
# max     4.446964e+06             NaN  ...  2.002000e+03  1.000000e+00
#
# [11 rows x 30 columns]

# %%
data.shape#we have 30 columns and 1111742 rows in our data
# Out:
# (1111742, 30)

# %%
data.isnull()
# Out:
#          Unnamed: 0     Id  groupId  ...  weaponsAcquired  winPoints  winPlacePerc
# 0             False  False    False  ...            False      False         False
# 1             False  False    False  ...            False      False         False
# 2             False  False    False  ...            False      False         False
# 3             False  False    False  ...            False      False         False
# 4             False  False    False  ...            False      False         False
# ...             ...    ...      ...  ...              ...        ...           ...
# 1111737       False  False    False  ...            False      False         False
# 1111738       False  False    False  ...            False      False         False
# 1111739       False  False    False  ...            False      False         False
# 1111740       False  False    False  ...            False      False         False
# ...

# %%
data.isnull().sum()#gives you the sum of null values in the respective column
# Out:
# Unnamed: 0         0
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %%
data.isna().any()
# Out:
# Unnamed: 0         False
# Id                 False
# groupId            False
# matchId            False
# assists            False
# boosts             False
# damageDealt        False
# DBNOs              False
# headshotKills      False
# heals              False
# killPlace          False
# killPoints         False
# kills              False
# killStreaks        False
# longestKill        False
# matchDuration      False
# matchType          False
# maxPlace           False
# numGroups          False
# rankPoints         False
# revives            False
# rideDistance       False
# roadKills          False
# swimDistance       False
# teamKills          False
# vehicleDestroys    False
# walkDistance       False
# weaponsAcquired    False
# winPoints          False
# winPlacePerc        True
# dtype: bool

# %%
# as we can see the null value is present in the winPlacePerc

# %%
##checking  duplicates records in the data
dupes = data.duplicated()
sum(dupes)
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'groupId', 'matchId', 'assists', 'boosts',
#        'damageDealt', 'DBNOs', 'headshotKills', 'heals', 'killPlace',
#        'killPoints', 'kills', 'killStreaks', 'longestKill', 'matchDuration',
#        'matchType', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc'],
#       dtype='object')

# %%
data.cov()# Prints the covariance of each attribute against every other attribute
# Out:
#                    Unnamed: 0      assists  ...      winPoints  winPlacePerc
# Unnamed: 0       1.648344e+12  1125.686277  ...   40651.612743    -56.658140
# assists          1.125686e+03     0.347396  ...      10.173522      0.053941
# boosts           1.257019e+03     0.310091  ...      -8.849029      0.334146
# damageDealt     -2.607179e+03    41.301777  ...    2277.270637     23.096779
# DBNOs           -3.834278e+02     0.204127  ...       8.883991      0.098394
# headshotKills    1.048397e+03     0.070939  ...       2.243788      0.051216
# heals           -2.240799e+03     0.361383  ...     -20.448162      0.352495
# killPlace        3.678028e+03    -4.695138  ...     -53.036855     -6.071465
# killPoints       4.139123e+04    14.174636  ...  456289.600790      2.524120
# kills            4.999125e+02     0.296552  ...       8.322772      0.200972
# killStreaks     -2.344237e+02     0.102268  ...       4.840657      0.082577
# ...

# %%
data.corr()  # prints the correlation coefficient between every pair of attributes
# Out:
#                  Unnamed: 0   assists  ...  winPoints  winPlacePerc
# Unnamed: 0         1.000000  0.001488  ...   0.000043     -0.000144
# assists            0.001488  1.000000  ...   0.023341      0.297738
# boosts             0.000571  0.306582  ...  -0.006973      0.633482
# damageDealt       -0.000012  0.409369  ...   0.017990      0.438973
# DBNOs             -0.000261  0.302200  ...   0.010483      0.279322
# headshotKills      0.001353  0.199487  ...   0.005029      0.276170
# heals             -0.000650  0.228456  ...  -0.010303      0.427296
# killPlace          0.000104 -0.289984  ...  -0.002611     -0.719051
# killPoints         0.000051  0.038331  ...   0.983443      0.013089
# kills              0.000249  0.322068  ...   0.007204      0.418527
# killStreaks       -0.000256  0.243386  ...   0.009182      0.376840
# longestKill        0.001358  0.260407  ...  -0.003930      0.408853
# matchDuration     -0.000414 -0.019399  ...  -0.086817     -0.005710
# ...

# %% [markdown]
# sns.pairplot(data, kind="reg")  # plots scatter plots for every pair of attributes and histograms along the diagonal
# plt.show()

# %%
fig,ax = plt.subplots(figsize=(20, 10))   
sns.heatmap(data.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f') 
plt.show()# as we can see more the correlation less the color

# %%
data['Id']
# Out:
# 0          a3e3cea9f2e314
# 1          43e4be7ad72cc7
# 2          9a68690e31fdff
# 3          b147e1bd448fc4
# 4          d818b4edd59612
#                 ...
# 1111737    43739241d6a8e8
# 1111738    d57c8a22a9e38b
# 1111739    c7ad131758ba55
# 1111740    8237d06ea2c508
# 1111741    9beb0064c56445
# Name: Id, Length: 1111742, dtype: object

# %%
data['Id'].count()
# Out:
# 1111742

# %%
a=data['Id'].unique()#uniqe function will give you the array of unique elements

# %%
len(a)
# Out:
# 1111742

# %%
#we can see there are no dublicate id's .every id is unique

# %%
data['groupId'].unique()
# Out:
# array(['c9f6eaa81245b5', '521836de101ee8', '4a72ffa2cebd90', ...,
#        '85e0624ddd2cb0', 'b3759687b385b3', '5cfa1834dc5b11'], dtype=object)

# %%
data['groupId'].nunique()#nunique will give you the no.of unique values
# Out:
# 870622

# %%
data['matchId'].nunique()
# Out:
# 47951

# %%
data['matchType'].value_counts()
# Out:
# squad-fpp           438781
# duo-fpp             249927
# squad               156573
# solo-fpp            133854
# duo                  78039
# solo                 45679
# normal-squad-fpp      4286
# crashfpp              1581
# normal-duo-fpp        1400
# flaretpp               633
# normal-solo-fpp        465
# flarefpp               180
# normal-squad           135
# crashtpp                86
# normal-solo             75
# normal-duo              48
# Name: matchType, dtype: int64

# %%
data.groupby(['matchType']).count()
# Out:
#                   Unnamed: 0      Id  ...  winPoints  winPlacePerc
# matchType                             ...
# crashfpp                1581    1581  ...       1581          1581
# crashtpp                  86      86  ...         86            86
# duo                    78039   78039  ...      78039         78039
# duo-fpp               249927  249927  ...     249927        249927
# flarefpp                 180     180  ...        180           180
# flaretpp                 633     633  ...        633           633
# normal-duo                48      48  ...         48            48
# normal-duo-fpp          1400    1400  ...       1400          1400
# normal-solo               75      75  ...         75            75
# normal-solo-fpp          465     465  ...        465           465
# normal-squad             135     135  ...        135           135
# normal-squad-fpp        4286    4286  ...       4286          4286
# ...

# %%
data.groupby(['matchType']).count().plot.bar()

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'groupId', 'matchId', 'assists', 'boosts',
#        'damageDealt', 'DBNOs', 'headshotKills', 'heals', 'killPlace',
#        'killPoints', 'kills', 'killStreaks', 'longestKill', 'matchDuration',
#        'matchType', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc', 'totaldistance', 'headshotusers', 'killswithoutmoving'],
#       dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0              Id  ... headshotusers killswithoutmoving
# 0     2093518  a3e3cea9f2e314  ...           NaN              False
# 1     3701672  43e4be7ad72cc7  ...           NaN              False
# 2     2059784  9a68690e31fdff  ...           NaN              False
# 3     1302036  b147e1bd448fc4  ...           NaN              False
# 4      297180  d818b4edd59612  ...           0.0              False
#
# [5 rows x 33 columns]

# %%
sns.distplot(data['kills'],kde="reg")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(y='matchType',data=data)
plt.show()#as we can see that the most of the players play squad-fpp

# %%
sns.boxplot(y="matchType",x="kills",data=data)
#as wecan see that most no.of kills are in normal-solo-fpp

# %%
#trying to find the relation between killls and matchduration
sns.scatterplot(x="heals",y="matchDuration",data=data)
#by seeing the avove plot we can say that there is slightly relation between them i.e:towards upards

# %%
sns.scatterplot(x="heals",y="kills",data=data)#trying to find a relation between heals and kills

# %%
sns.jointplot(x="heals",y="kills",data=data)

# %%
#by seeing the above plot we cannot determine wheather the heals and kills are related

# %%
# we can see that people mostly plays the squar-fpp match type

# %%
df=data.groupby(['matchType','matchId','groupId']).size().to_frame("no.of players")

# %%
df
# Out:
#                                          no.of players
# matchType matchId        groupId
# crashfpp  02abc00dbe6050 05283fd0dd3bd3              1
#                          20fec0939074eb              1
#                          274c09c6f17126              1
#                          31c376f4391282              1
#                          38884a77c5cdd6              1
# ...                                                ...
# squad-fpp fffe92232706aa abc744463b2dd4              1
#                          b671eab579d429              1
#                          bd5b4ecf8067ab              1
#                          d57f3a3ed40913              3
#                          d8fa9cfd6f9560              3
#
# [870622 rows x 1 columns]

# %%
df.head(10)
# Out:
#                                          no.of players
# matchType matchId        groupId
# crashfpp  02abc00dbe6050 05283fd0dd3bd3              1
#                          20fec0939074eb              1
#                          274c09c6f17126              1
#                          31c376f4391282              1
#                          38884a77c5cdd6              1
#                          547bf7879ce103              2
#                          5b048829513a08              1
#                          7969a814ccdf43              1
#                          7a5ea8096a3960              1
#                          9a964bf4b92c20              1

# %%
'''as we can see that with a match type of crashfpp and matchid of 02abc00dbe6050 and 
with  some groupids we can see the no.of players in the match'''
# Out:
# 'as we can see that with a match type of crashfpp and matchid of 02abc00dbe6050 and \nwith  some groupids we can see the no.of players in the match'

# %%
#the below code will help us to find the no.of illegal matches
data[data['winPlacePerc'].isnull()]
# Out:
#         Unnamed: 0              Id  ... winPoints winPlacePerc
# 184895     2744604  f70c74418bb064  ...         0          NaN
#
# [1 rows x 30 columns]

# %%
#as we can see there is a illegal match
#we need to remove that illegal match
data.drop(184895,inplace=True)

# %%
#check wheather the data is removed or not
data[data['winPlacePerc'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Id, groupId, matchId, assists, boosts, damageDealt, DBNOs, headshotKills, heals, killPlace, killPoints, kills, killStreaks, longestKill, matchDuration, matchType, maxPlace, numGroups, rankPoints, revives, rideDistance, roadKills, swimDistance, teamKills, vehicleDestroys, walkDistance, weaponsAcquired, winPoints, winPlacePerc]
# Index: []

# %%
#as we can see now there are no illegal matches

# %%
data['matchDuration'].hist(bins=20)

# %%
#as we can see the most of the match duration lies in 10 and 15 and some are above 35

# %%
data['matchDuration'].max()#maximum match duration of the maych is 2237(assume like secounds)
# Out:
# 2237

# %%
data['matchDuration'].min()#minimum duration of the match is 133(assume like seconds)
# Out:
# 133

# %% [markdown]
# **No.of Kills**

# %%
a=data[['matchType','teamKills']]

# %%
data['matchType'].value_counts()
# Out:
# squad-fpp           438781
# duo-fpp             249927
# squad               156573
# solo-fpp            133853
# duo                  78039
# solo                 45679
# normal-squad-fpp      4286
# crashfpp              1581
# normal-duo-fpp        1400
# flaretpp               633
# normal-solo-fpp        465
# flarefpp               180
# normal-squad           135
# crashtpp                86
# normal-solo             75
# normal-duo              48
# Name: matchType, dtype: int64

# %%
a.groupby('matchType').hist(bins=20)
# Out:
# matchType
# crashfpp            [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# crashtpp            [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# duo                 [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# duo-fpp             [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# flarefpp            [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# flaretpp            [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# normal-duo          [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# normal-duo-fpp      [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# normal-solo         [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# normal-solo-fpp     [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# normal-squad        [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# normal-squad-fpp    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# solo                [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# solo-fpp            [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# squad               [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# ...

# %%
# to find the totla distance traveled by the team 
data['totaldistance']=data['rideDistance']+data['swimDistance']+data['walkDistance']

# %%
data['totaldistance']
# Out:
# 0           151.300
# 1          1918.000
# 2          4908.000
# 3            38.810
# 4          2639.400
#              ...
# 1111737     799.800
# 1111738    4326.000
# 1111739      60.450
# 1111740    5819.000
# 1111741    4435.812
# Name: totaldistance, Length: 1111741, dtype: float64

# %%
data['totaldistance'].count()#total distance traveled by the players in the given datatset
# Out:
# 1111741

# %%
data.head()
# Out:
#    Unnamed: 0              Id  ... winPlacePerc totaldistance
# 0     2093518  a3e3cea9f2e314  ...       0.0667        151.30
# 1     3701672  43e4be7ad72cc7  ...       0.5862       1918.00
# 2     2059784  9a68690e31fdff  ...       0.8105       4908.00
# 3     1302036  b147e1bd448fc4  ...       0.5556         38.81
# 4      297180  d818b4edd59612  ...       0.6429       2639.40
#
# [5 rows x 31 columns]

# %%
data['headshotusers']=data['headshotKills']/data['kills']

# %%
data['headshotusers']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          0.0
#           ...
# 1111737    NaN
# 1111738    0.0
# 1111739    0.0
# 1111740    NaN
# 1111741    0.0
# Name: headshotusers, Length: 1111741, dtype: float64

# %%
data.head()
# Out:
#    Unnamed: 0              Id  ... totaldistance headshotusers
# 0     2093518  a3e3cea9f2e314  ...        151.30           NaN
# 1     3701672  43e4be7ad72cc7  ...       1918.00           NaN
# 2     2059784  9a68690e31fdff  ...       4908.00           NaN
# 3     1302036  b147e1bd448fc4  ...         38.81           NaN
# 4      297180  d818b4edd59612  ...       2639.40           0.0
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'groupId', 'matchId', 'assists', 'boosts',
#        'damageDealt', 'DBNOs', 'headshotKills', 'heals', 'killPlace',
#        'killPoints', 'kills', 'killStreaks', 'longestKill', 'matchDuration',
#        'matchType', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc', 'totaldistance', 'headshotusers'],
#       dtype='object')

# %%
#checkin the players who kills without moving ,which is not possible(which means outiers)
data['killswithoutmoving']=((data['kills']>0) & (data['totaldistance']==0))

# %%
data['killswithoutmoving']
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1111737    False
# 1111738    False
# 1111739    False
# 1111740    False
# 1111741    False
# Name: killswithoutmoving, Length: 1111741, dtype: bool

# %%
data.head()
# Out:
#    Unnamed: 0              Id  ... headshotusers killswithoutmoving
# 0     2093518  a3e3cea9f2e314  ...           NaN              False
# 1     3701672  43e4be7ad72cc7  ...           NaN              False
# 2     2059784  9a68690e31fdff  ...           NaN              False
# 3     1302036  b147e1bd448fc4  ...           NaN              False
# 4      297180  d818b4edd59612  ...           0.0              False
#
# [5 rows x 33 columns]

# %%
#checking the people whokilled without moving 
data[data['killswithoutmoving']==True]
# Out:
#          Unnamed: 0              Id  ... headshotusers killswithoutmoving
# 1267        1535402  c80731765f5704  ...      0.111111               True
# 2977        4061792  32cc8af554977f  ...      0.000000               True
# 5585        1573958  1ed752158c7bbc  ...      0.250000               True
# 9700        1845495  d4b5b144dbb5df  ...      0.000000               True
# 10092       3803166  861fd334addd94  ...      0.000000               True
# ...             ...             ...  ...           ...                ...
# 1096635     2690397  15a7eb09e76467  ...      0.000000               True
# 1104975     3453115  8a1c5168a10715  ...      0.333333               True
# 1106140      236349  bb85ea21268d4a  ...      0.266667               True
# 1109190     2534604  82de69757c681c  ...      0.176471               True
# 1111372     1028552  8e998c8011b1a9  ...      0.000000               True
#
# [375 rows x 33 columns]

# %%
data[data['killswithoutmoving']==True].shape
# Out:
# (375, 33)

# %%
#as we can see there are 375 records are present who can kill without moving, which is not possible

# %%
#we are goinng to drop those values who can kill with out moving

# %%
data.drop(data[data['killswithoutmoving']==True].index,inplace=True)#which helps us to remove the particular rows form the data

# %%
#checking the data is removed successfully or not
data['killswithoutmoving']
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1111737    False
# 1111738    False
# 1111739    False
# 1111740    False
# 1111741    False
# Name: killswithoutmoving, Length: 1111366, dtype: bool

# %%
sns.distplot(data['longestKill'])
plt.show()#longest kill gives us from how far the player is killed
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data['longestKill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
display(data[data['longestKill']>=1000].shape)
data[data['longestKill']>=1000].head()#finding the people who killed players far from 1000mtrs
# Out:
# (6, 33)
#         Unnamed: 0              Id  ... headshotusers killswithoutmoving
# 101252     1209416  528659ff1c1aec  ...      0.466667              False
# 567594     4332473  d8857d3d7e31b6  ...      0.187500              False
# 644598      324313  ef390c152bcc3d  ...      0.000000              False
# 878056     2015559  5ff0c1a9fab2ba  ...      0.545455              False
# 900761     2981715  7f77051c7cef52  ...      0.333333              False
#
# [5 rows x 33 columns]

# %%
#this are the people who killed the players far from the 1000mtrs which is not possible
#for that we need to remove the rows/records of those who can kill the player far from 1000mtrs

# %%
data.drop(data[data['longestKill']>=1000].index,inplace=True)

# %%
#after doing some operation on the i would like to see my original data

# %%
data.shape
# Out:
# (1111360, 33)

# %%
#at first we have 30 columns and 1111742 rows in our data
#now we have 1111360 rows and 33 columns ,33 columns because we added some columns like killswithourtmoving,headshortusers,totaldistance
#we can also see some are decreased because we removed some records which gives us wrong insights

# %%
data.head()
# Out:
#    Unnamed: 0              Id  ... headshotusers killswithoutmoving
# 0     2093518  a3e3cea9f2e314  ...           NaN              False
# 1     3701672  43e4be7ad72cc7  ...           NaN              False
# 2     2059784  9a68690e31fdff  ...           NaN              False
# 3     1302036  b147e1bd448fc4  ...           NaN              False
# 4      297180  d818b4edd59612  ...           0.0              False
#
# [5 rows x 33 columns]

# %% [markdown]
# # IMPACT IN NATIONWIDE – Research Paper on Pubg
# In India, Millichronicle reports that Gujarat banned this game and the proposal is raised for banning the game all over the country. . A heavy drop in the academic level of children who could not handle this addiction is the major reason. They made a comparative analysis before and after PUBG and found the above analysis, which is a serious impact on kids as well as their parents. Furthermore, youngsters are posed to serious psychological problems like stress, loneliness, violence, short temper, etc. In addition to this, there is a drastic change in their behavior towards family and most importantly no sense of responsibilities from their side in PhD Publication.

# %%
#in consideration the people whoa are playing for more time they are they are affecting 
#for suppose the people whoa are playing it for more than 4 hours a day they are suffering

# %% [markdown]
# # Applying: t-test

# %% [markdown]
# # Step - 1:
# Alternate Hypothesis (Bold Claim): $$ H_1: \mu>4\  $$
# Null Hypothesis (Status Quo): $$ H_0: \mu<=4\  $$
#
# Step - 2:
# * Collect a sample of size n = 10 $$ [4, 3, 5, 4, 5, 3, 5, 5, 4, 2, 4, 5, 5, 4, 4, 5, 4, 5, 4, 5] $$
# * Compute sample mean $$ \bar{x} \ = \ 2.5 $$
#
# Step - 3:
# Compute Test Statistic: $$ t = \frac{\bar{x} - \mu}{s/\sqrt[2]{n}}$$
#
#
#
# $s^2=\sum_{i=0}^{n}\,\frac{(obs-\mu)^2}{n-1}$
#
# $$s=\sqrt[]{s^2}$$
#
# Step - 4:
# Decide $ \alpha $
#
# Step - 5.1: right tailed t-test: $$ \ if\   t > t_{n-1,\alpha} \Rightarrow Accept \ H_1 \ or \ Reject \ H_0 $$
#
# Step - 5.2: Compute p-value

# %%
# One tail
from scipy.stats import t
critical=0.95
alpha = 1 - critical

t_critical = t.ppf(1-alpha, df = 9)

print(t_critical)
# Out:
# 1.8331129326536335

# %% [markdown]
# $$s^2=\sum_{i=0}^{n}\,\frac{(obs-\mu)^2}{n-1}$$
#
# $$s=\sqrt[]{s^2}$$

# %%
def s_std(a):
  ll=a
  n=len(ll)
  mean=sum(ll)/n
  sum1=0
  for i in range(n):
    sum1+=(ll[i]-mean)**2
  ss=sum1/(n-1)
  s=ss**0.5
  return s

# %%
l=[4, 3, 5, 4, 5, 3, 5, 5, 4, 2, 4, 5, 5, 4, 4, 5, 4, 5, 4, 5]
sum(l)/len(l)
# Out:
# 4.25

# %%
s=s_std(l)
print(s)
# Out:
# 0.8506963092234007

# %%
# Defining the sample and population parameters

sample_size = 20
sample_mean = 4.25
pop_mean = 4
sample_std = 0.8

# %%
# t_score for sampling distributions

def t_score(sample_size, sample_mean, pop_mean, pop_std):
    numerator = sample_mean - pop_mean
    denomenator = sample_std / sample_size**0.5
    return numerator / denomenator

# %%
t = t_score(sample_size, sample_mean, pop_mean, sample_std)

print(t)
# Out:
# 0.9882117688026186

# %%
from scipy.stats import norm

# %%
# Ploting the sampling distribution with rejection regions

# Defining the x minimum and x maximum
x_min = 3.5
x_max = 4.5


# Defining the sampling distribution mean and sampling distribution std
mean = pop_mean
std = sample_std / sample_size**0.5


# Ploting the graph and setting the x limits
x = np.linspace(x_min, x_max, 100)
y = norm.pdf(x, mean, std)
plt.xlim(x_min, x_max)
plt.plot(x, y)
# Computing the left and right critical values (Two tailed Test)
t_critical_left = pop_mean + (-t_critical * std)
t_critical_right = pop_mean + (t_critical * std)


# Shading the left rejection region
x1 = np.linspace(x_min, t_critical_left, 100)
y1 = norm.pdf(x1, mean, std)
plt.fill_between(x1, y1, color='orange')


# Shading the right rejection region
x2 = np.linspace(t_critical_right, x_max, 100)
y2 = norm.pdf(x2, mean, std)
plt.fill_between(x2, y2, color='orange')


# Ploting the sample mean and concluding the results 
plt.scatter(sample_mean, 0)
plt.annotate("x_bar", (sample_mean, 0.0007))


# In this case sample mean falls in the rejection region
# i.e. here we reject the Null Hypothesis
# Out:
# Text(4.25, 0.0007, 'x_bar')

# %%
if(t > t_critical):
    print("Reject Null Hypothesis")
else:
    print("Fail to reject Null Hypothesis")
# Out:
# Fail to reject Null Hypothesis

# %%
# Conclusion using p test for singletailed test

p_value = 1.0 - norm.cdf(np.abs(t))

print("p_value = ", p_value)

if(p_value < alpha):
    print("Reject Null Hypothesis")
else:
    print("Fail to reject Null Hypothesis")
# Out:
# p_value =  0.16152447280046256
# Fail to reject Null Hypothesis

# %% [markdown]
# # yes, the conclusion says that the people who plays for more than 4 hours are affected
